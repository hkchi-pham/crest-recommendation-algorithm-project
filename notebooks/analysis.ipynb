# %%
import sys

sys.path.append("../src")

from diversity_metrics import (
    genre_diversity,
    genre_coverage,
    shannon_entropy
)

from data_loader import load_data

import visualization
# Out:
# Genre diversity:  4
# Genre coverage:  80.0
# Shannon entropy:  1.9182958340544893
