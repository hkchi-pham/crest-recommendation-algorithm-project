# %%
import pandas as pd

from diversity_metrics import (
    genre_diversity,
    genre_coverage,
    shannon_entropy
)

import visualization
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 from diversity_metrics import (
#       4     genre_diversity,
#       5     genre_coverage,
#       6     shannon_entropy
#
# ModuleNotFoundError: No module named 'diversity_metrics'
